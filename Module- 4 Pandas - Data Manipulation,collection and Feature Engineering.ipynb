# %% [markdown]
# # Data Manipulation

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Module 4 
Data Manipulation, 
Collecting & Feature 
Engineering 
Data Manipulation 
Pandas and its Features I Data Structures I Series, Panel I Dataframes I Data 
Operations I Data Standa dization I Pandas SQL Operations 
Collecting Data 
Understanding the domain and the dataset I Importing and Exporting Data I Basic 
Insights from dataset 
Data Cleaning 
Feature Engineering I Normalization, Indicator Variables and Binning

# %%
# Data Manipulation

# %% [markdown]
# - learn objective:
# -  the building blocks of the Pandas
#         - Series,
#         - DataFrames,and
#         - Indexes,
#  - Understand the various functions in this library that are used to tidy,cleanse, merge, and aggregate data in Pandas.
#  - develop the skills necessary for preparing your data.

# %% [markdown]
# ### Pandas at a glance
# - Wes McKinney developed the Pandas library in 2008.
# - The name (Pandas) comes from the term “Panel Data” used in econometrics for analyzing time-series data.

# %% [markdown]
# ### Pandas and its Features

# %% [markdown]
# 1. Pandas provides features for labeling of data or indexing, which speeds up the retrieval of data.
# 2. Input and output support: Pandas provides options to read data from different file formats like
#     - JSON (JavaScript Object Notation),
#     - CSV (Comma-Separated Values),
#     - Excel, and
#     - HDF5 (Hierarchical Data Format Version 5).
#     - It can also be used to write data into databases, web services, and so on.
# 3. Most of the data that is needed for analysis is not contained in a single source, and we often need to combine datasets to consolidate the data that we need for analysis. Again, Pandas comes to the rescue with tailor-made functions to combine data.
#  4. Speed and enhanced performance:
#     - The Pandas library is based on Cython, which combines the convenience and ease of use of Python with the speed of the C language. Cython helps to optimize performance and reduce overheads.
# 5. Data visualization:
#     - To derive insights from the data and make it presentable to the audience, viewing data using visual means is crucial, and Pandas provides a lot of built-in visualization tools using Matplotlib as the base library.
# 6. Support for other libraries:
#     - Pandas integrates smoothly with other libraries like Numpy, Matplotlib, Scipy, and Scikit-learn.Thus we can perform other tasks like numerical computations, visualizations, statistical analysis, and machine learning in conjunction with data manipulation.
# 7. Grouping:
#     - Pandas provides support for the split-apply-combine methodology, whereby we can group our data into categories, apply separate functions on them, and combine the results.
# 8. Handling missing data, duplicates, and filler characters:
#     - Data often has missing values, duplicates, blank spaces, special characters (like $, &),and so on that may need to be removed or replaced. With the functions provided in Pandas, you can handle such anomalies with ease.
# 9. Mathematical operations:
#     - Many numerical operations and computations can be performed in Pandas, with NumPy being used at the back end for this purpose.

# %% [markdown]
# # Pandas DataStructure

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # read data

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# read CSV data
import pandas as pd
url='https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/olympics.csv'
olympics=pd.read_csv(url,skiprows=4)
olympics
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
 # read from Excell
storm_data=pd.read_excel("storm.xlsx",sheet_name='Storm_Detail')
storm_data
# Out:
#         Season Basin Sub_basin      Name            ISO_time Type  Latitude  \
# 0         1980    SI        MM    ALBINE 1979-11-27 06:00:00   NR     -10.0
# 1         1980    SI        MM    ALBINE 1979-11-27 12:00:00   NR     -10.1
# 2         1980    SI        MM    ALBINE 1979-11-27 18:00:00   NR     -10.2
# 3         1980    SI        MM    ALBINE 1979-11-28 00:00:00   NR     -10.6
# 4         1980    SI        MM    ALBINE 1979-11-28 06:00:00   TS     -10.8
# ...        ...   ...       ...       ...                 ...  ...       ...
# 108030    2016    WP        MM  NOCK-TEN 2016-12-27 12:00:00   TS      14.2
# 108031    2016    WP        MM  NOCK-TEN 2016-12-27 18:00:00   TS      13.3
# 108032    2016    WP        MM  NOCK-TEN 2016-12-28 00:00:00   TS      13.0
# 108033    2016    WP        MM  NOCK-TEN 2016-12-28 06:00:00   TS      11.9
# 108034    2016    WP        MM  NOCK-TEN 2016-12-28 12:00:00   TS      11.2
#
# ...

# %%
 # read from Excell
storm_data=pd.read_excel("storm.xlsx",sheet_name=[0,1,2,3,4,5,6])
storm_data
# Out:
# {0:       Season      Name Basin Type  MaxWindMPH  MinPressure  StartDate  \
#  0       1980       NaN   NaN   TS        35.0          NaN 1980-07-17
#  1       1980     ALLEN   NaN   TS       190.0        899.0 1980-07-31
#  2       1980    BONNIE   NaN   ET        98.0        975.0 1980-08-14
#  3       1980   CHARLEY   NaN   TS        81.0        989.0 1980-08-20
#  4       1980  DANIELLE   NaN   TS        58.0       1004.0 1980-09-04
#  ...      ...       ...   ...  ...         ...          ...        ...
#  3113    2016     URIAH    SI   ET       127.0        925.0 2016-02-09
#  3114    2016    VICTOR    SP   NR        92.0        958.0 2016-01-14
#  3115    2016   WINSTON    SP   NR       173.0        884.0 2016-02-10
#  3116    2016      YALO    SP   NR        46.0        100.0 2016-02-24
#  3117    2016      ZENA    SP   NR        81.0        975.0 2016-04-05
#
#          EndDate Hem NS Hem EW   Lat    Lon
#  0    1980-11-18      N      W  25.7  -91.2
# ...

# %%
type(storm_data)
# Out:
# dict

# %%
storm_data[6]
# Out:
#   Sub_Basin      SubBasin_Name
# 0        AS        Arabian Sea
# 1        BB      Bay of Bengal
# 2        EA  Eastern Australia
# 3        WA  Western Australia
# 4        CP    Central Pacific
# 5        CS      Caribbean Sea
# 6        GM     Gulf of Mexico
# 7        MM            Missing

# %%
# read Html Table

# %%
table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')
table_MN
# Out:
# [                                            Minnesota  \
#  0                                               State
#  1   .mw-parser-output .ib-settlement-cols{text-ali...
#  2   Nickname(s): Land of 10,000 Lakes;North Star S...
#  3   Motto: L'Étoile du Nord (French: The Star of t...
#  4                           Anthem: "Hail! Minnesota"
#  5   Map of the United States with Minnesota highli...
#  6                                             Country
#  7                                    Before statehood
#  8                               Admitted to the Union
#  9                                             Capital
#  10                                       Largest city
#  11                      Largest metro and urban areas
#  12                                         Government
#  13                                         • Governor
#  14                              • Lieutenant Governor
#  15                                        Legislature
# ...

# %%
type(table_MN)
# Out:
# list

# %%
table_MN[2]
# Out:
#               Location July (°F) July (°C) January (°F) January (°C)
# 0          Minneapolis     83/64     28/18         23/7       −4/−13
# 1           Saint Paul     83/63     28/17         23/6       −5/−14
# 2            Rochester     82/63     28/17         23/3       −5/−16
# 3               Duluth     76/55     24/13         19/1       −7/−17
# 4            St. Cloud     81/58     27/14        18/−1       −7/−18
# 5              Mankato     86/62     30/16         23/3       −5/−16
# 6  International Falls     77/52     25/11        15/−6       −9/−21

# %%
table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota',match='Average daily maximum and minimum temperatures for selected cities in Minnesota')
table_MN[0]
# Out:
#               Location July (°F) July (°C) January (°F) January (°C)
# 0          Minneapolis     83/64     28/18         23/7       −4/−13
# 1           Saint Paul     83/63     28/17         23/6       −5/−14
# 2            Rochester     82/63     28/17         23/3       −5/−16
# 3               Duluth     76/55     24/13         19/1       −7/−17
# 4            St. Cloud     81/58     27/14        18/−1       −7/−18
# 5              Mankato     86/62     30/16         23/3       −5/−16
# 6  International Falls     77/52     25/11        15/−6       −9/−21

# %%
# read Json file
import pandas as pd
url="https://raw.githubusercontent.com/svkarthik86/Advanced-python/main/countries.json"
json_data=pd.read_json(url)
json_data.head()
# Out:
#    id            name iso3 iso2  ...   latitude longitude emoji           emojiU
# 0   1     Afghanistan  AFG   AF  ...  33.000000      65.0    🇦🇫  U+1F1E6 U+1F1EB
# 1   2   Aland Islands  ALA   AX  ...  60.116667      19.9    🇦🇽  U+1F1E6 U+1F1FD
# 2   3         Albania  ALB   AL  ...  41.000000      20.0    🇦🇱  U+1F1E6 U+1F1F1
# 3   4         Algeria  DZA   DZ  ...  28.000000       3.0    🇩🇿  U+1F1E9 U+1F1FF
# 4   5  American Samoa  ASM   AS  ... -14.333333    -170.0    🇦🇸  U+1F1E6 U+1F1F8
#
# [5 rows x 20 columns]

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as connection
import pandas as pd
mydb=connection.connect(host="localhost", database = 'data_science', user="root", passwd="edubridge@123")
query="Select * from books"
result_df=pd.read_sql(query,mydb)
result_df
# Out:
# C:\Users\karthick\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    id         book_name    author_name date_created
# 0   1   THe Hunger Game  suznne collin   2008-09-14
# 1   2  Harry poter Game    J.K Rowling   1997-07-30
# 2   3         Divergent  Veronica Roth   2011-04-25

# %%
import mysql.connector as connection
import pandas as pd
mydb=connection.connect(host="localhost", database = 'data_science', user="root", passwd="edubridge@123")
query="SELECT * FROM data_science.customer;"
result_df=pd.read_sql(query,mydb)
result_df
# Out:
# C:\Users\karthick\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    id   name          city  age
# 0   1   John      New York   35
# 1   2  David   Los Angeles   23
# 2   3  Chloe       Chicago   27
# 3   4  Emily       Houston   34
# 4   5  James  Philadelphia   31

# %% [markdown]
# # Data Operation

# %% [markdown]
# # Row and column selection

# %%
import pandas as pd
url="https://raw.githubusercontent.com/svkarthik86/Assignment/main/Sales_Data/Sales_January_2019.csv"
sales_data=pd.read_csv(url)
sales_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
#acessing first five rows of data
sales_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
sales_data.loc[0:5,:]
# Out:
#   Order ID  ...                        Purchase Address
# 0   141234  ...         944 Walnut St, Boston, MA 02215
# 1   141235  ...        185 Maple St, Portland, OR 97035
# 2   141236  ...   538 Adams St, San Francisco, CA 94016
# 3   141237  ...      738 10th St, Los Angeles, CA 90001
# 4   141238  ...           387 10th St, Austin, TX 73301
# 5   141239  ...  775 Willow St, San Francisco, CA 94016
#
# [6 rows x 6 columns]

# %%
sales_data.iloc[0:6,:]
# Out:
#   Order ID  ...                        Purchase Address
# 0   141234  ...         944 Walnut St, Boston, MA 02215
# 1   141235  ...        185 Maple St, Portland, OR 97035
# 2   141236  ...   538 Adams St, San Francisco, CA 94016
# 3   141237  ...      738 10th St, Los Angeles, CA 90001
# 4   141238  ...           387 10th St, Austin, TX 73301
# 5   141239  ...  775 Willow St, San Francisco, CA 94016
#
# [6 rows x 6 columns]

# %%
sales_data.iloc[0:6,[2,4]]
# Out:
#   Quantity Ordered      Order Date
# 0                1  01/22/19 21:25
# 1                1  01/28/19 14:15
# 2                2  01/17/19 13:33
# 3                1  01/05/19 20:33
# 4                1  01/25/19 11:59
# 5                1  01/29/19 20:22

# %%
sales_data.axes
# Out:
# [RangeIndex(start=0, stop=9723, step=1),
#  Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#         'Purchase Address'],
#        dtype='object')]

# %%
sales_data['Order ID']
# Out:
# 0       141234
# 1       141235
# 2       141236
# 3       141237
# 4       141238
#          ...
# 9718    150497
# 9719    150498
# 9720    150499
# 9721    150500
# 9722    150501
# Name: Order ID, Length: 9723, dtype: object

# %%
sales_data[['Order ID', 'Price Each']]
# Out:
#      Order ID Price Each
# 0      141234        700
# 1      141235      14.95
# 2      141236      11.99
# 3      141237     149.99
# 4      141238      11.99
# ...       ...        ...
# 9718   150497     109.99
# 9719   150498     149.99
# 9720   150499     999.99
# 9721   150500       2.99
# 9722   150501        600
#
# [9723 rows x 2 columns]

# %%
# object . method
sales_data.Product
# Out:
# 0                         iPhone
# 1       Lightning Charging Cable
# 2               Wired Headphones
# 3               27in FHD Monitor
# 4               Wired Headphones
#                   ...
# 9718                20in Monitor
# 9719            27in FHD Monitor
# 9720             ThinkPad Laptop
# 9721      AAA Batteries (4-pack)
# 9722                Google Phone
# Name: Product, Length: 9723, dtype: object

# %%
#clean are correct to valid  column names 
sales_data.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
sales_data.columns.str.replace(" ","_")
# Out:
# Index(['Order_ID', 'Product', 'Quantity_Ordered', 'Price_Each', 'Order_Date',
#        'Purchase_Address'],
#       dtype='object')

# %%
sales_data.columns=sales_data.columns.str.replace(" ","_")

# %%
sales_data
# Out:
#      Order_ID  ...                       Purchase_Address
# 0      141234  ...        944 Walnut St, Boston, MA 02215
# 1      141235  ...       185 Maple St, Portland, OR 97035
# 2      141236  ...  538 Adams St, San Francisco, CA 94016
# 3      141237  ...     738 10th St, Los Angeles, CA 90001
# 4      141238  ...          387 10th St, Austin, TX 73301
# ...       ...  ...                                    ...
# 9718   150497  ...            95 8th St, Dallas, TX 75001
# 9719   150498  ...    403 7th St, San Francisco, CA 94016
# 9720   150499  ...        214 Main St, Portland, OR 97035
# 9721   150500  ...      810 2nd St, Los Angeles, CA 90001
# 9722   150501  ...         428 Cedar St, Boston, MA 02215
#
# [9723 rows x 6 columns]

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9723 entries, 0 to 9722
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          9697 non-null   object
#  1   Product           9697 non-null   object
#  2   Quantity_Ordered  9697 non-null   object
#  3   Price_Each        9697 non-null   object
#  4   Order_Date        9697 non-null   object
#  5   Purchase_Address  9697 non-null   object
# dtypes: object(6)
# memory usage: 455.9+ KB

# %%
# Create New column as total_cost=Quantity_Ordered*Price_Each

# %%
sales_data['total_cost']=sales_data.Quantity_Ordered*sales_data.Price_Each

# %%
sales_data.Price_Each.astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 sales_data.Price_Each.astype('float')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %% [markdown]
# # find NaN value and Clean the data

# %%
sales_data.isna().sum()
# Out:
# Order_ID            26
# Product             26
# Quantity_Ordered    26
# Price_Each          26
# Order_Date          26
# Purchase_Address    26
# dtype: int64

# %%
sales_data[sales_data.Price_Each.isna()]
# Out:
#      Order_ID Product Quantity_Ordered Price_Each Order_Date Purchase_Address
# 664       NaN     NaN              NaN        NaN        NaN              NaN
# 678       NaN     NaN              NaN        NaN        NaN              NaN
# 797       NaN     NaN              NaN        NaN        NaN              NaN
# 876       NaN     NaN              NaN        NaN        NaN              NaN
# 1299      NaN     NaN              NaN        NaN        NaN              NaN
# 1491      NaN     NaN              NaN        NaN        NaN              NaN
# 1699      NaN     NaN              NaN        NaN        NaN              NaN
# 3047      NaN     NaN              NaN        NaN        NaN              NaN
# 3082      NaN     NaN              NaN        NaN        NaN              NaN
# 3584      NaN     NaN              NaN        NaN        NaN              NaN
# 3659      NaN     NaN              NaN        NaN        NaN              NaN
# ...

# %%
sales_data.iloc[664:679,:] # sample of NaN values
# Out:
#     Order_ID  ...                            Purchase_Address
# 664      NaN  ...                                         NaN
# 665   141881  ...            563 Wilson St, Seattle, WA 98101
# 666   141882  ...       55 Lakeview St, Los Angeles, CA 90001
# 667   141883  ...              320 River St, Dallas, TX 75001
# 668   141884  ...            74 1st St, Los Angeles, CA 90001
# 669   141885  ...             544 West St, Portland, OR 97035
# 670   141886  ...          94 7th St, New York City, NY 10001
# 671   141887  ...        374 10th St, San Francisco, CA 94016
# 672   141888  ...         17 Spruce St, Los Angeles, CA 90001
# 673   141889  ...               12 Cedar St, Boston, MA 02215
# 674   141890  ...  962 Washington St, New York City, NY 10001
# 675   141891  ...           800 Lincoln St, Atlanta, GA 30301
# 676   141892  ...      888 Walnut St, San Francisco, CA 94016
# 677   141893  ...    527 Lakeview St, New York City, NY 10001
# ...

# %%
# Remove NaN values  -  method1: dropna()
sales_data.dropna()
# Out:
#      Order_ID  ...                       Purchase_Address
# 0      141234  ...        944 Walnut St, Boston, MA 02215
# 1      141235  ...       185 Maple St, Portland, OR 97035
# 2      141236  ...  538 Adams St, San Francisco, CA 94016
# 3      141237  ...     738 10th St, Los Angeles, CA 90001
# 4      141238  ...          387 10th St, Austin, TX 73301
# ...       ...  ...                                    ...
# 9718   150497  ...            95 8th St, Dallas, TX 75001
# 9719   150498  ...    403 7th St, San Francisco, CA 94016
# 9720   150499  ...        214 Main St, Portland, OR 97035
# 9721   150500  ...      810 2nd St, Los Angeles, CA 90001
# 9722   150501  ...         428 Cedar St, Boston, MA 02215
#
# [9697 rows x 6 columns]

# %%
9722-9697
# Out:
# 25

# %%
# remove NaN value using Complement Method  ~
sales_data[~(sales_data.Price_Each.isna())]
# Out:
#      Order_ID  ...                       Purchase_Address
# 0      141234  ...        944 Walnut St, Boston, MA 02215
# 1      141235  ...       185 Maple St, Portland, OR 97035
# 2      141236  ...  538 Adams St, San Francisco, CA 94016
# 3      141237  ...     738 10th St, Los Angeles, CA 90001
# 4      141238  ...          387 10th St, Austin, TX 73301
# ...       ...  ...                                    ...
# 9718   150497  ...            95 8th St, Dallas, TX 75001
# 9719   150498  ...    403 7th St, San Francisco, CA 94016
# 9720   150499  ...        214 Main St, Portland, OR 97035
# 9721   150500  ...      810 2nd St, Los Angeles, CA 90001
# 9722   150501  ...         428 Cedar St, Boston, MA 02215
#
# [9697 rows x 6 columns]

# %%
9722-9697
# Out:
# 25

# %%
sales_data.dropna(inplace=True) # inmemory dropna

# %%
#duplicate Data
sales_data.duplicated() #Return boolean Series denoting duplicate rows.
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9718    False
# 9719    False
# 9720    False
# 9721    False
# 9722    False
# Length: 9697, dtype: bool

# %%
sales_data[sales_data.duplicated()]
# Out:
#       Order_ID  ...                           Purchase_Address
# 875     142071  ...               131 2nd St, Boston, MA 02215
# 1102  Order ID  ...                           Purchase Address
# 1194  Order ID  ...                           Purchase Address
# 1897  Order ID  ...                           Purchase Address
# 2463  Order ID  ...                           Purchase Address
# 3115  Order ID  ...                           Purchase Address
# 3247  Order ID  ...                           Purchase Address
# 3612  Order ID  ...                           Purchase Address
# 3623  Order ID  ...                           Purchase Address
# 4126    145143  ...  182 Jefferson St, San Francisco, CA 94016
# 4901  Order ID  ...                           Purchase Address
# 5593  Order ID  ...                           Purchase Address
# 5811    146765  ...   918 Highland St, New York City, NY 10001
# 6506  Order ID  ...                           Purchase Address
# ...

# %%
#drop_duplicates()
temp_df=sales_data.drop_duplicates() #Return DataFrame with duplicate rows removed.

# %%
temp_df[temp_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Product, Quantity_Ordered, Price_Each, Order_Date, Purchase_Address]
# Index: []

# %%
sales_data[sales_data.Price_Each=='Price Each']
# Out:
#       Order_ID  Product  ...  Order_Date  Purchase_Address
# 1073  Order ID  Product  ...  Order Date  Purchase Address
# 1102  Order ID  Product  ...  Order Date  Purchase Address
# 1194  Order ID  Product  ...  Order Date  Purchase Address
# 1897  Order ID  Product  ...  Order Date  Purchase Address
# 2463  Order ID  Product  ...  Order Date  Purchase Address
# 3115  Order ID  Product  ...  Order Date  Purchase Address
# 3247  Order ID  Product  ...  Order Date  Purchase Address
# 3612  Order ID  Product  ...  Order Date  Purchase Address
# 3623  Order ID  Product  ...  Order Date  Purchase Address
# 4901  Order ID  Product  ...  Order Date  Purchase Address
# 5593  Order ID  Product  ...  Order Date  Purchase Address
# 6506  Order ID  Product  ...  Order Date  Purchase Address
# 7544  Order ID  Product  ...  Order Date  Purchase Address
# 7674  Order ID  Product  ...  Order Date  Purchase Address
# 8271  Order ID  Product  ...  Order Date  Purchase Address
# ...

# %%
sales_data=sales_data[~(sales_data.Price_Each=='Price Each')]

# %%
sales_data
# Out:
#      Order_ID  ...                       Purchase_Address
# 0      141234  ...        944 Walnut St, Boston, MA 02215
# 1      141235  ...       185 Maple St, Portland, OR 97035
# 2      141236  ...  538 Adams St, San Francisco, CA 94016
# 3      141237  ...     738 10th St, Los Angeles, CA 90001
# 4      141238  ...          387 10th St, Austin, TX 73301
# ...       ...  ...                                    ...
# 9718   150497  ...            95 8th St, Dallas, TX 75001
# 9719   150498  ...    403 7th St, San Francisco, CA 94016
# 9720   150499  ...        214 Main St, Portland, OR 97035
# 9721   150500  ...      810 2nd St, Los Angeles, CA 90001
# 9722   150501  ...         428 Cedar St, Boston, MA 02215
#
# [9681 rows x 6 columns]

# %%
sales_data['total_cost']=sales_data.Quantity_Ordered.astype('int64')*sales_data.Price_Each.astype('float')
# Out:
# C:\Users\karthick\AppData\Local\Temp\ipykernel_26008\3973141348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data['total_cost']=sales_data.Quantity_Ordered.astype('int64')*sales_data.Price_Each.astype('float')

# %%
sales_data
# Out:
#      Order_ID  ... total_cost
# 0      141234  ...     700.00
# 1      141235  ...      14.95
# 2      141236  ...      23.98
# 3      141237  ...     149.99
# 4      141238  ...      11.99
# ...       ...  ...        ...
# 9718   150497  ...     109.99
# 9719   150498  ...     149.99
# 9720   150499  ...     999.99
# 9721   150500  ...       5.98
# 9722   150501  ...     600.00
#
# [9681 rows x 7 columns]

# %% [markdown]
# # Query The DataFrame

# %%
sales_data[~(sales_data['total_cost']>=1700)]   # select * from sales_data where not total_cost>=1700
# Out:
#      Order_ID  ... total_cost
# 0      141234  ...     700.00
# 1      141235  ...      14.95
# 2      141236  ...      23.98
# 3      141237  ...     149.99
# 4      141238  ...      11.99
# ...       ...  ...        ...
# 9718   150497  ...     109.99
# 9719   150498  ...     149.99
# 9720   150499  ...     999.99
# 9721   150500  ...       5.98
# 9722   150501  ...     600.00
#
# [9445 rows x 7 columns]

# %%
# logical condition use binary operator for query using index [] operator    &,|,~

# %%
sales_data[(sales_data['total_cost']>600) & (sales_data['Product']=='iPhone')] 
#select * from sales_data where total_cost>600 and product is iphone
# Out:
#      Order_ID Product  ...                          Purchase_Address total_cost
# 0      141234  iPhone  ...           944 Walnut St, Boston, MA 02215      700.0
# 104    141336  iPhone  ...        811 Hickory St, Portland, OR 97035      700.0
# 164    141394  iPhone  ...      534 12th St, San Francisco, CA 94016      700.0
# 207    141437  iPhone  ...    377 Meadow St, New York City, NY 10001      700.0
# 228    141457  iPhone  ...         820 Jackson St, Seattle, WA 98101      700.0
# ...       ...     ...  ...                                       ...        ...
# 9567   150349  iPhone  ...  532 Lakeview St, San Francisco, CA 94016      700.0
# 9579   150361  iPhone  ...            915 Pine St, Atlanta, GA 30301      700.0
# 9588   150370  iPhone  ...    534 Sunset St, San Francisco, CA 94016      700.0
# 9641   150422  iPhone  ...            255 14th St, Seattle, WA 98101      700.0
# 9707   150486  iPhone  ...            57 Wilson St, Dallas, TX 75001      700.0
#
# ...

# %%
#using Query()  # and,or not
sales_data.query("(total_cost>600) and (Product=='iPhone')")
# Out:
#      Order_ID Product  ...                          Purchase_Address total_cost
# 0      141234  iPhone  ...           944 Walnut St, Boston, MA 02215      700.0
# 104    141336  iPhone  ...        811 Hickory St, Portland, OR 97035      700.0
# 164    141394  iPhone  ...      534 12th St, San Francisco, CA 94016      700.0
# 207    141437  iPhone  ...    377 Meadow St, New York City, NY 10001      700.0
# 228    141457  iPhone  ...         820 Jackson St, Seattle, WA 98101      700.0
# ...       ...     ...  ...                                       ...        ...
# 9567   150349  iPhone  ...  532 Lakeview St, San Francisco, CA 94016      700.0
# 9579   150361  iPhone  ...            915 Pine St, Atlanta, GA 30301      700.0
# 9588   150370  iPhone  ...    534 Sunset St, San Francisco, CA 94016      700.0
# 9641   150422  iPhone  ...            255 14th St, Seattle, WA 98101      700.0
# 9707   150486  iPhone  ...            57 Wilson St, Dallas, TX 75001      700.0
#
# ...

# %%
sales_data
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
sales_data.Product.value_counts().index[0]
# Out:
# 'USB-C Charging Cable'

# %%
sales_data.Product.unique()#.size
# Out:
# array(['iPhone', 'Lightning Charging Cable', 'Wired Headphones',
#        '27in FHD Monitor', 'AAA Batteries (4-pack)',
#        '27in 4K Gaming Monitor', 'USB-C Charging Cable',
#        'Bose SoundSport Headphones', 'Apple Airpods Headphones',
#        'Macbook Pro Laptop', 'Flatscreen TV', 'Vareebadd Phone',
#        'AA Batteries (4-pack)', 'Google Phone', '20in Monitor',
#        '34in Ultrawide Monitor', 'ThinkPad Laptop', 'LG Dryer',
#        'LG Washing Machine', nan, 'Product'], dtype=object)

# %%
go=sales_data.groupby('Product')

# %%
print(dir(go))
# Out:
# ['Product', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_accessors', '_agg_examples_doc', '_agg_general', '_agg_py_fallback', '_aggregate_frame', '_aggregate_item_by_item', '_aggregate_with_numba', '_apply_allowlist', '_apply_filter', '_apply_to_column_groupbys', '_ascending_count', '_bool_agg', '_can_use_transform_fast', '_choose_path', '_concat_objects', '_constructor', '_cumcount_array', '_cython_agg_general', '_cython_transform', '_define_paths', '_descending_count', '_dir_additions', '_dir_deletions', '_fill', '_get_cythonized_result', '_get_da
# ...

# %%
go.get_group('iPhone')
# Out:
#      Order ID Product Quantity Ordered Price Each      Order Date  \
# 0      141234  iPhone                1        700  01/22/19 21:25
# 104    141336  iPhone                1        700  01/09/19 18:23
# 164    141394  iPhone                1        700  01/06/19 16:54
# 207    141437  iPhone                1        700  01/10/19 15:40
# 228    141457  iPhone                1        700  01/09/19 22:11
# ...       ...     ...              ...        ...             ...
# 9567   150349  iPhone                1        700  01/21/19 22:21
# 9579   150361  iPhone                1        700  01/30/19 06:41
# 9588   150370  iPhone                1        700  01/21/19 21:34
# 9641   150422  iPhone                1        700  01/21/19 16:31
# 9707   150486  iPhone                1        700  01/26/19 15:52
#
#                               Purchase Address
# 0              944 Walnut St, Boston, MA 02215
# 104         811 Hickory St, Portland, OR 97035
# ...
